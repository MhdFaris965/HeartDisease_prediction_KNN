# %% [markdown]
# Heart DISEASE Prediction Quantum Dataset

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Heart Prediction Quantum Dataset.csv')

# %%
df
# Out:
#      Age  Gender  BloodPressure  Cholesterol  HeartRate  \
# 0     68       1            105          191        107
# 1     58       0             97          249         89
# 2     44       0             93          190         82
# 3     72       1             93          183        101
# 4     37       0            145          166        103
# ..   ...     ...            ...          ...        ...
# 495   34       0            126          292        116
# 496   41       0            164          248        114
# 497   45       1            159          175         75
# 498   55       0            107          157        101
# 499   55       0            174          249         89
#
#      QuantumPatternFeature  HeartDisease
# 0                 8.362241             1
# 1                 9.249002             0
# 2                 7.942542             1
# 3                 6.495155             1
# 4                 7.653900             1
# ..                     ...           ...
# 495               9.303403             0
# 496               9.067889             0
# 497               8.718708             0
# 498               7.337650             1
# 499              10.492950             0
#
# [500 rows x 7 columns]

# %%
sns.countplot(data=df,x='Gender')
plt.title('Plot of Gender')
plt.show()

# %%
sns.countplot(data=df,x='HeartDisease')
plt.title('Plot of HeartDisease')
plt.show()

# %%
import Faris_Stats as fs

# %%
for i in('Age','BloodPressure','Cholesterol','HeartRate','QuantumPatternFeature'):
    print(i)
    fs.cal_pr(df[i])
    print('-'*100)
# Out:
# Age
# Total Revenue 27432
# Total_count 500
# Mean 54.864
# median 55.0
# minimum 30
# Maximum 79
# range 49
# variance 204.50950399999996
# Standard deviation 14.300681941781656
# Quartile 1 : 43.0
# quartile 3 : 66.25
# inter quartile range 23.25
# lower_whisker 8.125
# upper_whisker 101.125
# Skewness -0.10559629619505961
# kurtosis -1.1105776246525663
# ----------------------------------------------------------------------------------------------------
# BloodPressure
# Total Revenue 66437
# Total_count 500
# Mean 132.874
# median 132.0
# minimum 90
# Maximum 179
# range 89
# variance 696.5421240000002
# Standard deviation 26.39208449516635
# Quartile 1 : 111.0
# quartile 3 : 155.0
# inter quartile range 44.0
# lower_whisker 45.0
# upper_whisker 221.0
# Skewness 0.07548811031849383
# kurtosis -1.1760535275248203
# ----------------------------------------------------------------------------------------------------
# Cholesterol
# Total Revenue 110750
# Total_count 500
# Mean 221.5
# median 221.0
# minimum 150
# Maximum 299
# range 149
# variance 1920.17
# Standard deviation 43.819744408200286
# Quartile 1 : 183.75
# quartile 3 : 258.0
# inter quartile range 74.25
# lower_whisker 72.375
# upper_whisker 369.375
# Skewness 0.09603709914485536
# kurtosis -1.2268671684722114
# ----------------------------------------------------------------------------------------------------
# HeartRate
# Total Revenue 44383
# Total_count 500
# Mean 88.766
# median 89.0
# minimum 60
# Maximum 119
# range 59
# variance 302.75524399999983
# Standard deviation 17.399863332796606
# Quartile 1 : 73.0
# quartile 3 : 104.0
# inter quartile range 31.0
# lower_whisker 26.5
# upper_whisker 150.5
# Skewness -0.003964199458562421
# kurtosis -1.232195305704595
# ----------------------------------------------------------------------------------------------------
# QuantumPatternFeature
# Total Revenue 4158.703722397
# Total_count 500
# Mean 8.317407444794
# median 8.323063611
# minimum 6.164692103
# Maximum 10.78488616
# range 4.620194056999999
# variance 0.8440259223100857
# Standard deviation 0.9187088343485578
# Quartile 1 : 7.6757793145
# quartile 3 : 8.93599865975
# inter quartile range 1.2602193452500003
# lower_whisker 5.785450296624999
# upper_whisker 10.826327677625
# Skewness 0.0756232707661455
# kurtosis -0.40449707136054247
# ----------------------------------------------------------------------------------------------------

# %%
for i in ('Age','BloodPressure','Cholesterol','HeartRate','QuantumPatternFeature'):
    print(i)
    sns.displot(df[i])
    plt.show()
# Out:
# Age
# BloodPressure
# Cholesterol
# HeartRate
# QuantumPatternFeature

# %%
for i in ('Age','BloodPressure','Cholesterol','HeartRate','QuantumPatternFeature'):
    print(i)
    sns.boxplot(df[i])
    plt.show()
# Out:
# Age
# BloodPressure
# Cholesterol
# HeartRate
# QuantumPatternFeature

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop('HeartDisease',axis=1)
y=df['HeartDisease']

# %%
#STANDARD NORMAL DISTIBUTION
#VARIANCE =1
#MEAN = 0
#scaling feature
from sklearn.preprocessing import StandardScaler

# %%
for i in df.columns:
    print(i,df[i].mean())
# Out:
# Age 54.864
# Gender 0.468
# BloodPressure 132.874
# Cholesterol 221.5
# HeartRate 88.766
# QuantumPatternFeature 8.317407444794
# HeartDisease 0.6

# %%
ss=StandardScaler()
X=ss.fit_transform(X)

# %%
X=pd.DataFrame(data=X,columns=['Age ','Gender ','BloodPressure ','Cholesterol ','HeartRate ','QuantumPatternFeature '])
for i in X.columns:
    print(i,X[i].mean())
# Out:
# Age  -7.105427357601002e-18
# Gender  -4.796163466380676e-17
# BloodPressure  -2.1316282072803006e-17
# Cholesterol  -1.2434497875801754e-17
# HeartRate  -1.2878587085651817e-17
# QuantumPatternFeature  -3.552713678800501e-18

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred_train=knn.predict(X_train)
y_pred_test=knn.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90       134
#            1       0.93      0.95      0.94       201
#
#     accuracy                           0.92       335
#    macro avg       0.92      0.92      0.92       335
# weighted avg       0.92      0.92      0.92       335

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80        66
#            1       0.87      0.86      0.86        99
#
#     accuracy                           0.84       165
#    macro avg       0.83      0.83      0.83       165
# weighted avg       0.84      0.84      0.84       165

# %%
error_rates = []#list all errors

for i in range(1,21): #for loop trying different values
    knn=KNeighborsClassifier(n_neighbors=i) # Making Model
    knn.fit(X_train,y_train) #Fitting Training Data
    y_pred_test=knn.predict(X_test) #predicting on testing Data
    error=np.mean(y_pred_test!=y_test) #calculating error
    error_rates.append(error) #adding that error to error_rates

# %%
#ELBOW METHOD
plt.figure(figsize=(10,5),)
plt.plot(range(1,21),error_rates,marker='o',linestyle='--')
plt.title('Error Rate vs K value')
plt.xlabel('K value')
plt.ylabel('Error Rates')
# Out:
# Text(0, 0.5, 'Error Rates')

# %%
for i in X.columns:
    print(i)
# Out:
# Age
# Gender
# BloodPressure
# Cholesterol
# HeartRate
# QuantumPatternFeature

# %%
Age=int(input('Please Enter the Age here'))
Gender=int(input('Please Enter The Gender here'))
BloodPressure=int(input('Please enter the Bloodpressure here'))
Cholesterol=int(input('please enter Cholesterol here'))
HeartRate=int(input('please enter the Heartrate here'))
QuantumPatternFeature=float(input('please enter the QuantumPatternfeature')) 

user_input = np.array([Age,Gender,BloodPressure,Cholesterol,HeartRate,QuantumPatternFeature]).reshape(1,-1)

if knn.predict(user_input)==0:
    print('Hoorray you have not heart disease ')
else:
    print('Sorry you have heart disease')
# Out:
# Hoorray you have not heart disease
# c:\Users\muham\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
